# %%
from pypot.creatures import PoppyHumanoid

poppy = PoppyHumanoid(simulator='vrep')
print("Poppy succesfully loaded!")
# Out:
# ---------------------------------------------------------------------------
# VrepConnectionError                       Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\creatures\abstractcreature.py:103, in AbstractPoppyCreature.__new__(cls, base_path, config, simulator, scene, host, port, id, shared_vrep_io, use_snap, snap_host, snap_port, snap_quiet, use_http, http_host, http_port, http_quiet, use_remote, remote_host, remote_port, use_ws, ws_host, ws_port, start_background_services, sync, **extra)
#     102 try:
# --> 103     poppy_creature = from_vrep(config, host, port, scene if scene != "keep-existing" else None, id=id, shared_vrep_io=shared_vrep_io)
#     104 except VrepConnectionError:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\vrep\__init__.py:88, in from_vrep(config, vrep_host, vrep_port, scene, tracked_objects, tracked_collisions, id, shared_vrep_io)
#      87 if shared_vrep_io is None:
# ---> 88     vrep_io = VrepIO(vrep_host, vrep_port)
#      89 else:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\vrep\io.py:70, in VrepIO.__init__(self, vrep_host, vrep_port, scene, start)
#      58 # self.client_id = remote_api.simxStart(
#      59 #     vrep_host, vrep_port, True, True, 5000, 5)
#      60 # if self.client_id == -1:
#    (...)     67 # if scene is not None:
#      68 #     self.load_scene(scene, start)
# ---> 70 self.open_io()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\vrep\io.py:80, in VrepIO.open_io(self)
#      76     msg = ('Could not connect to V-REP server on {}:{}. '
#      77            'This could also means that you still have '
#      78            'a previously opened connection running! '
#      79            '(try pypot.vrep.close_all_connections())')
# ---> 80     raise VrepConnectionError(
#      81         msg.format(self.vrep_host, self.vrep_port))
#      83 if self.scene is not None:
#
# VrepConnectionError: Could not connect to V-REP server on 127.0.0.1:19997. This could also means that you still have a previously opened connection running! (try pypot.vrep.close_all_connections())
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 3
#       1 from pypot.creatures import PoppyHumanoid
#       2
# ----> 3 poppy = PoppyHumanoid(simulator='vrep')
#       4 print("Poppy succesfully loaded!")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\creatures\abstractcreature.py:105, in AbstractPoppyCreature.__new__(cls, base_path, config, simulator, scene, host, port, id, shared_vrep_io, use_snap, snap_host, snap_port, snap_quiet, use_http, http_host, http_port, http_quiet, use_remote, remote_host, remote_port, use_ws, ws_host, ws_port, start_background_services, sync, **extra)
#     103         poppy_creature = from_vrep(config, host, port, scene if scene != "keep-existing" else None, id=id, shared_vrep_io=shared_vrep_io)
#     104     except VrepConnectionError:
# --> 105         raise IOError('Connection to V-REP failed!')
#     107 elif simulator == 'poppy-simu':
#     108     use_http = True
#
# OSError: Connection to V-REP failed!

# %%
poppy.motors
# Out:
# [<DxlMotor name=l_elbow_y id=44 pos=0.0>,
#  <DxlMotor name=r_hip_y id=23 pos=-0.0>,
#  <DxlMotor name=r_knee_y id=24 pos=0.0>,
#  <DxlMotor name=head_y id=37 pos=-3.8999999999999986>,
#  <DxlMotor name=r_ankle_y id=25 pos=0.3>,
#  <DxlMotor name=r_arm_z id=53 pos=-0.0>,
#  <DxlMotor name=head_z id=36 pos=-0.0>,
#  <DxlMotor name=r_shoulder_x id=52 pos=-0.9000000000000057>,
#  <DxlMotor name=r_shoulder_y id=51 pos=0.0>,
#  <DxlMotor name=r_hip_z id=22 pos=-0.1>,
#  <DxlMotor name=r_hip_x id=21 pos=0.5>,
#  <DxlMotor name=r_elbow_y id=54 pos=0.0>,
#  <DxlMotor name=l_arm_z id=43 pos=0.0>,
#  <DxlMotor name=l_hip_x id=11 pos=-0.2>,
#  <DxlMotor name=l_hip_y id=13 pos=-2.0>,
#  <DxlMotor name=l_hip_z id=12 pos=0.1>,
#  <DxlMotor name=abs_x id=32 pos=0.0>,
#  <DxlMotor name=abs_y id=31 pos=0.1>,
#  <DxlMotor name=abs_z id=33 pos=0.0>,
#  <DxlMotor name=l_ankle_y id=15 pos=0.2>,
#  <DxlMotor name=bust_y id=34 pos=0.2>,
#  <DxlMotor name=bust_x id=35 pos=0.0>,
#  <DxlMotor name=l_knee_y id=14 pos=0.0>,
#  <DxlMotor name=l_shoulder_x id=42 pos=0.4000000000000057>,
#  <DxlMotor name=l_shoulder_y id=41 pos=-0.5>]

# %%
poppy.l_shoulder_y
# Out:
# <DxlMotor name=l_shoulder_y id=41 pos=-0.4000000000000057>

# %%
poppy.head_y.present_position
# Out:
# np.float64(-4.0)

# %%
[m.present_position for m in poppy.motors]
# Out:
# [np.float64(0.0),
#  np.float64(-0.0),
#  np.float64(0.0),
#  np.float64(-4.0),
#  np.float64(0.2),
#  np.float64(-0.0),
#  np.float64(-0.0),
#  np.float64(-1.0),
#  np.float64(0.0),
#  np.float64(-0.1),
#  np.float64(0.4),
#  np.float64(-0.0),
#  np.float64(-0.0),
#  np.float64(-0.2),
#  np.float64(-2.0),
#  np.float64(0.1),
#  np.float64(0.0),
#  np.float64(0.1),
#  np.float64(0.0),
#  np.float64(0.2),
#  np.float64(0.2),
#  np.float64(0.0),
#  np.float64(0.0),
#  np.float64(0.4000000000000057),
#  np.float64(-0.4000000000000057)]

# %%
{m.name: m.present_position for m in poppy.motors}
# Out:
# {'l_elbow_y': np.float64(0.0),
#  'r_hip_y': np.float64(-0.0),
#  'r_knee_y': np.float64(0.0),
#  'head_y': np.float64(-4.0),
#  'r_ankle_y': np.float64(0.3),
#  'r_arm_z': np.float64(-0.0),
#  'head_z': np.float64(-0.0),
#  'r_shoulder_x': np.float64(-1.0),
#  'r_shoulder_y': np.float64(0.0),
#  'r_hip_z': np.float64(-0.1),
#  'r_hip_x': np.float64(0.5),
#  'r_elbow_y': np.float64(0.0),
#  'l_arm_z': np.float64(-0.0),
#  'l_hip_x': np.float64(-0.1),
#  'l_hip_y': np.float64(-2.0),
#  'l_hip_z': np.float64(0.1),
#  'abs_x': np.float64(0.0),
#  'abs_y': np.float64(0.1),
#  'abs_z': np.float64(-0.0),
#  'l_ankle_y': np.float64(0.2),
#  'bust_y': np.float64(0.2),
#  'bust_x': np.float64(0.0),
#  'l_knee_y': np.float64(0.0),
#  'l_shoulder_x': np.float64(0.4000000000000057),
#  'l_shoulder_y': np.float64(-0.4000000000000057)}

# %%
poppy.alias
# Out:
# ['r_leg',
#  'l_leg_sagitall',
#  'l_leg',
#  'head',
#  'r_arm',
#  'legs',
#  'torso',
#  'r_leg_sagitall',
#  'l_arm',
#  'arms']

# %%
{m.name: m.present_position for m in poppy.r_leg}
# Out:
# {'r_hip_x': np.float64(0.4),
#  'r_hip_z': np.float64(-0.1),
#  'r_hip_y': np.float64(-0.0),
#  'r_knee_y': np.float64(0.0),
#  'r_ankle_y': np.float64(0.3)}

# %%
poppy.head_z.goal_position = 90.

# %%
for m in poppy.l_arm:
    m.goal_position = 30.

# %%
poppy.r_shoulder_x.goal_position = 30
poppy.r_shoulder_x.goal_position = -30

# %%
poppy.reset_simulation()

# %%
poppy.head_z.goto_position(-45, 2)

# %%
poppy.head_z.goto_position(45, 2, wait=False)
poppy.head_y.goto_position(-30, 2, wait=True)

poppy.head_z.goto_position(0, 2, wait=True)

poppy.head_y.goto_position(20, 1, wait=True)

# %%
poppy.head_y.goto_behavior
# Out:
# 'dummy'

# %%
poppy.head_y.goto_behavior = 'dummy'

# %% [markdown]
# # Read and Write

# %%
poppy.reset_simulation()

# %%
import time

import math

amp = 30 # in degrees
freq = 0.5 # in Hz

t0 = time.time()

while True:
    t = time.time()
    
    # run for 10s
    if t - t0 > 10:
        break

    poppy.head_z.goal_position = amp * math.sin(2 * 3.14 * freq * t)
    
    time.sleep(0.04)

# %%
current, goal = [], []

t0 = time.time()

while True:
    t = time.time()
    
    # run for 5s
    if t - t0 > 5:
        break

    poppy.head_z.goal_position = amp * math.sin(2 * 3.14 * freq * t)

    
    current.append(poppy.head_z.present_position)
    goal.append(poppy.head_z.goal_position)
    
    time.sleep(0.04)

# %%
# %pylab inline

t = linspace(0, 5, len(current))
plot(t, goal)
plot(t, current)

legend(('goal', 'current'))
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
poppy.l_shoulder_x.goto_behavior = 'minjerk'

poppy.l_shoulder_x.goto_position(120, 5)

pos = []
t0 = time.time()

while time.time() - t0 < 5:
    pos.append(poppy.l_shoulder_x.present_position)
    
    time.sleep(0.01)
    
t = linspace(0, 5, len(pos))
plot(t, pos)
# Out:
# Exception in thread Thread-8 (_wrapped_target):
# Traceback (most recent call last):
#   File "c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\utils\stoppablethread.py", line 130, in _wrapped_target
#     self._target()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\utils\stoppablethread.py", line 205, in run
#     make_update_loop(self, self._update)
#   File "c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\utils\stoppablethread.py", line 175, in make_update_loop
#     update_func()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\utils\trajectory.py", line 81, in update
#     self.motor.goal_position = self.trajs(self.elapsed_time)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\utils\trajectory.py", line 60, in <lambda>
#     return lambda x: numpy.piecewise(x, self.domain(x), [self._generators[j] for j in range(len(self._generators))] + [self.finals[-1]])
#                                         ^^^^^^^^^^^^^^
#   File "c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pypot\utils\trajectory.py", line 45, in domain
#     if not isinstance(x, collections.Iterable):
#                          ^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'collections' has no attribute 'Iterable'

# %% [markdown]
# # Tracking Object

# %%
poppy.get_object_position('l_forearm_visual')
# Out:
# [0.10264979302883148, 0.01788698136806488, 0.41657590866088867]

# %%
poppy.get_object_position('l_forearm_visual', 'head_visual')
# Out:
# [-0.10295646637678146, -0.3164539039134979, -0.12078432738780975]

# %%
reached_pt = []

for m in poppy.l_arm:
    m.goto_behavior = 'minjerk'

# We generate 25 random arm configuration
# and stores the reached position of the forearm
for _ in range(25):
    poppy.reset_simulation()
    
    # Generate a position by setting random position (within the angle limit) to each joint
    # This can be hacked to define other exploration
    pos = {m.name: randint(min(m.angle_limit), max(m.angle_limit)) for m in poppy.l_arm}    
    poppy.goto_position(pos, 2., wait=True)
        
    reached_pt.append(poppy.get_object_position('l_forearm_visual'))

# %%
from mpl_toolkits.mplot3d import Axes3D

ax = axes(projection='3d')
ax.scatter(*array(reached_pt).T)

# %%
poppy.reset_simulation()

# %% [markdown]
# # Using Primitives

# %%
from pypot.primitive.utils import Sinus

# %%
sin_1 = Sinus(poppy, 25., [poppy.head_z, poppy.head_y], amp=15, freq=.15)

# %%
sin_1.start()

# %%
sin_2 = Sinus(poppy, 25., [poppy.head_z, ], amp=8, freq=.5)
sin_2.start()

# %%
from pypot.primitive import LoopPrimitive

class MotorPositionLogger(LoopPrimitive):
    def __init__(self, robot, refresh_freq, motor):
        LoopPrimitive.__init__(self, robot, refresh_freq)
        
        self.motor = getattr(self.robot, motor.name)

    # This code will be called each time the primitive is started
    def setup(self):
        self.positions = []
       
    # This method will be called at the predefined frequency
    def update(self):
        self.positions.append(self.motor.present_position)

# %%
logger = MotorPositionLogger(poppy, 50, poppy.head_z)

# %%
logger.start()

time.sleep(10)
sin_2.pause()

time.sleep(15)
sin_2.resume()

time.sleep(5)
logger.stop()

pos = logger.positions

plot(linspace(0, 30, len(pos)), pos)

# %%
for p in poppy.active_primitives:
    p.stop()
